# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df = pd.read_csv("/kaggle/input/ams580-data/train.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26049 entries, 0 to 26048
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             26049 non-null  int64
#  1   workclass       26049 non-null  object
#  2   fnlwgt          26049 non-null  int64
#  3   education       26049 non-null  object
#  4   education-num   26049 non-null  int64
#  5   marital-status  26049 non-null  object
#  6   occupation      26049 non-null  object
#  7   relationship    26049 non-null  object
#  8   race            26049 non-null  object
#  9   sex             26049 non-null  object
#  10  capital-gain    26049 non-null  int64
#  11  capital-loss    26049 non-null  int64
#  12  hours-per-week  26049 non-null  int64
#  13  native-country  26049 non-null  object
#  14  income          26049 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.0+ MB

# %%
cols = df.columns.tolist()
print(cols)
# Out:
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']

# %%
df[df == " ?"] = np.nan
df.isnull().sum()
# Out:
# age                  0
# workclass         1471
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1476
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     450
# income               0
# dtype: int64

# %%
fig1 = plt.figure(figsize = (15,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["age"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("age", loc='center', fontsize=16)
plt.xlabel("age", fontsize=14)
plt.ylabel("frequency", fontsize=14)
# Out:
# Text(0, 0.5, 'frequency')

# %%
fig2 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["workclass"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("workclass", loc='center', fontsize=16)
plt.xlabel("workclass", fontsize=14)
plt.ylabel("frequency", fontsize=14)
# Out:
# Text(0, 0.5, 'frequency')

# %%
df["workclass"].value_counts()
# Out:
# workclass
# Private             18166
# Self-emp-not-inc     2011
# Local-gov            1674
# State-gov            1020
# Self-emp-inc          915
# Federal-gov           774
# Without-pay            13
# Never-worked            5
# Name: count, dtype: int64

# %%
fig3 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(df["fnlwgt"], bins=30, rwidth=0.8)
plt.title("fnlwgt", loc='center', fontsize=16)
plt.xlabel("fnlwgt", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
fig3 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(np.log(df["fnlwgt"]), bins=30, rwidth=0.8)
plt.title("log fnlwgt", loc='center', fontsize=16)
plt.xlabel("fnlwgt", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
fig4 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["education"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("education", loc='center', fontsize=16)
plt.xlabel("education", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
fig5 = plt.figure(figsize = (6,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["marital-status"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("marital-status", loc='center', fontsize=16)
plt.xlabel("marital-status", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
fig6 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["occupation"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("occupation", loc='center', fontsize=16)
plt.xlabel("occupation", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
fig7 = plt.figure(figsize = (6,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["relationship"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("relationship", loc='center', fontsize=16)
plt.xlabel("relationship", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
fig8 = plt.figure(figsize = (6,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["race"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("race", loc='center', fontsize=16)
plt.xlabel("race", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
fig9 = plt.figure(figsize = (4,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["sex"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("sex", loc='center', fontsize=16)
plt.xlabel("sex", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
df1 = df[df["capital-gain"]>0]["capital-gain"]

fig9 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(df["capital-gain"], bins=116, rwidth=0.8)
plt.title("capital-gain", loc='center', fontsize=16)
plt.xlabel("capital-gain", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
fig9 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(np.log(df1), bins=115, rwidth=0.8)
plt.title("capital-gain, >0", loc='center', fontsize=16)
plt.xlabel("capital-gain, >0", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
df2 = df[df["capital-loss"]>0]["capital-loss"]

fig9 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(df["capital-loss"], bins=88, rwidth=0.8)
plt.title("capital-loss", loc='center', fontsize=16)
plt.xlabel("capital-loss", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
fig9 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(np.log(df2), bins=87, rwidth=0.8)
plt.title("capital-loss, >0", loc='center', fontsize=16)
plt.xlabel("capital-loss, >0", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
fig10 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(df["capital-gain"]-df["capital-loss"], bins=100, rwidth=0.8)
plt.title("capital_gain - capital_loss", loc='center', fontsize=16)
plt.xlabel("capital_gain - capital_loss", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
df3 = df[df["capital-gain"]-df["capital-loss"] != 0]

fig10 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist((df3["capital-gain"]-df3["capital-loss"]), bins=100, rwidth=0.8)
plt.title("capital_gain - capital_loss", loc='center', fontsize=16)
plt.xlabel("capital_gain - capital_loss", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
fig11 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.hist(df["hours-per-week"], bins=93, rwidth=0.8)
plt.title("hours-per-week", loc='center', fontsize=16)
plt.xlabel("hours-per-week", fontsize=14)
plt.ylabel("counts", fontsize=14)
# Out:
# Text(0, 0.5, 'counts')

# %%
fig12 = plt.figure(figsize = (12,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["native-country"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("native-country", loc='center', fontsize=16)
plt.xlabel("native-country", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
fig13 = plt.figure(figsize = (4,5))
plt.grid(axis='y', linestyle='--', linewidth=0.5)
vc = df["income"].value_counts()
plt.bar(vc.index, vc.values/df.shape[0])
plt.title("income", loc='center', fontsize=16)
plt.xlabel("income", fontsize=14)
plt.ylabel("frequency", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
